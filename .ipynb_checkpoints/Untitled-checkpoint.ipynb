# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
global_data = pd.read_csv('./data/global_selected.csv',header=None,names=['streams', 'acousticness', 'danceability', 'energy', 'loudness',
       'tempo', 'valence'])
filand_data = pd.read_csv('./data/finland_selected.csv',header=None,names=['streams', 'acousticness', 'danceability', 'energy', 'loudness',
       'tempo', 'valence'])
sweden_data = pd.read_csv('./data/sweden_selected.csv',header=None,names=['streams', 'acousticness', 'danceability', 'energy', 'loudness',
       'tempo', 'valence'])

# %% [markdown]
# ## Exploratory Data Analysis
#
# From pair distribution plot we can see that:
# 1. number of streams is long tail left skewed: most songs have less views with a few having a lot of views
# 2. energy and loudness is highly correlated, which is to be expected since one of the measurement of enengy is loudness
# 3. none of the audio features appear to have really strong linear correlation with number of streams

# %%
sns.pairplot(global_data)

# %% [markdown]
# ## Model with bayesian linear regression

# %%
import pystan

# %%
with open('linear_regression.stan') as file:
    print(file.read())
# Out:
# data{
#     int N; // number of data points
#     int<lower=0> y[N]; // target value: number of streams
#     real acousticness[N];
#     real danceability[N];
#     real energy[N];
#     real loudness[N];
#     real tempo[N];
#     real valence[N];
# }
#
# parameters{
#     real a;
#     real b1;
#     real b2;
#     real b3;
#     real b4;
#     real b5;
#     real b6;
#     real<lower=0> sigma;
# }
#
# model{
#     for (i in 1:N)
#         y[i] ~ normal(a+b1*acousticness[i]+b2*danceability[i]+b3*energy[i]+b4*loudness[i]+b5*tempo[i]+b6*valence[i],sigma);
# }

# %%
gb = global_data.values
data = dict(N=gb.shape[0],y=gb[:,0],acousticness=gb[:,1], danceability=gb[:,2],  
            energy=gb[:,3], loudness=gb[:,4], tempo=gb[:,5], valence=gb[:,6])

# %%
fit = pystan.stan(file='linear_regression.stan',data=data,seed=42)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_6e24b874466a6bdbcf8291785c5fd94a NOW.
# --------------------------------------------------
# DistutilsExecErrorTraceback (most recent call last)
# ~/anaconda3/lib/python3.6/distutils/unixccompiler.py in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     117             self.spawn(compiler_so + cc_args + [src, '-o', obj] +
# --> 118                        extra_postargs)
#     119         except DistutilsExecError as msg:
#
# ~/anaconda3/lib/python3.6/distutils/ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# ~/anaconda3/lib/python3.6/distutils/spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      35     if os.name == 'posix':
# ---> 36         _spawn_posix(cmd, search_path, dry_run=dry_run)
#      37     elif os.name == 'nt':
#
# ...
